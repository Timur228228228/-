# %% [markdown]
# <a href="https://colab.research.google.com/github/Timur228228228/-/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO
import gzip, base64

plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['axes.grid'] = True

def read_embedded_csv(b64_text):
    raw = gzip.decompress(base64.b64decode(b64_text.encode('utf-8')))
    return pd.read_csv(BytesIO(raw))

embedded_data = {
    'new_year_day_2015_delayed_flights.csv': '''''',
    'new_year_day_2015_as_flights.csv': '''''',
    'new_year_day_2015_dl_flights.csv': '''''',
    'airlines.csv': '''''',
    'airports.csv': '''''',
}

fl = read_embedded_csv(embedded_data['new_year_day_2015_delayed_flights.csv'])
as_flights = read_embedded_csv(embedded_data['new_year_day_2015_as_flights.csv'])
dl_flights = read_embedded_csv(embedded_data['new_year_day_2015_dl_flights.csv'])
airlines = read_embedded_csv(embedded_data['airlines.csv'])
airports = read_embedded_csv(embedded_data['airports.csv'])

fl = fl.merge(airlines, left_on='AIRLINE', right_on='IATA_CODE', how='left')
fl = fl.drop(columns=['IATA_CODE']).rename(columns={'AIRLINE_x': 'AIRLINE_CODE', 'AIRLINE_y': 'AIRLINE_NAME'})

fl = fl.merge(
    airports[['IATA_CODE', 'AIRPORT', 'CITY', 'STATE']],
    left_on='ORIGIN_AIRPORT',
    right_on='IATA_CODE',
    how='left'
).rename(columns={'AIRPORT': 'ORIGIN_AIRPORT_NAME', 'CITY': 'ORIGIN_CITY', 'STATE': 'ORIGIN_STATE'})
fl = fl.drop(columns=['IATA_CODE'])

fl['ROUTE'] = fl['ORIGIN_AIRPORT'] + ' → ' + fl['DESTINATION_AIRPORT']
fl['SCHEDULED_HOUR'] = fl['SCHEDULED_DEPARTURE'].fillna(0).astype(int).floordiv(100)

print('Данные загружены из встроенного блока.')
print(f'Задержанных рейсов: {len(fl)}')
print(f'Авиакомпаний: {fl["AIRLINE_CODE"].nunique()}')
print(f'Аэропортов вылета: {fl["ORIGIN_AIRPORT"].nunique()}')
print(f'Маршрутов: {fl["ROUTE"].nunique()}')
# Out:
# Данные загружены из встроенного блока.
# Задержанных рейсов: 1820
# Авиакомпаний: 13
# Аэропортов вылета: 160
# Маршрутов: 1210

# %% [markdown]
# Краткое замечание по данным.
#
# В этой версии использован вшитый в ноутбук срез по задержанным рейсам за 1 января 2015 года и два полных дневных среза по авиакомпаниям AS и DL. Этого достаточно, чтобы показать проблемные зоны, различия между авиакомпаниями, аэропортами, маршрутами и временем вылета.

# %% [markdown]
# Результат 1. Какие причины дают основную массу минут задержки?
#
# Сначала полезно понять не просто среднюю задержку, а источник этих минут. Так становится видно, где проблема внешняя, а где она рождается внутри самой операционной системы.

# %%
causes = {
    'AIRLINE_DELAY': 'Авиакомпания',
    'LATE_AIRCRAFT_DELAY': 'Позднее прибытие самолёта',
    'AIR_SYSTEM_DELAY': 'Система управления воздушным движением',
    'WEATHER_DELAY': 'Погода',
    'SECURITY_DELAY': 'Безопасность'
}

cause_minutes = fl[list(causes)].sum().rename(index=causes).sort_values(ascending=False)
cause_share = (cause_minutes / cause_minutes.sum() * 100).round(1)

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(cause_share.index, cause_share.values)
ax.set_title('Доля минут задержки по причинам')
ax.set_ylabel('Доля, %')
ax.set_xlabel('Причина')
plt.xticks(rotation=20, ha='right')
plt.tight_layout()
plt.show()

for name, value in cause_share.items():
    print(f'{name}: {value:.1f}%')
# Out:
# Авиакомпания: 60.2%
# Позднее прибытие самолёта: 28.4%
# Система управления воздушным движением: 11.0%
# Погода: 0.2%
# Безопасность: 0.2%

# %% [markdown]
# Вывод.
#
# Основная масса минут задержки связана с самой авиакомпанией и с эффектом позднего прибытия самолёта на следующий рейс. Погода и безопасность почти не влияют на общую картину в этом срезе. Значит, главная проблема здесь не внешняя, а операционная.

# %% [markdown]
# Результат 2. У каких авиакомпаний задержки наиболее тяжёлые?
#
# Важно разделять число задержанных рейсов и среднюю тяжесть задержки. Большой поток рейсов ещё не означает самую плохую ситуацию по качеству.

# %%
airline_stats = (
    fl.groupby(['AIRLINE_CODE', 'AIRLINE_NAME'])
      .agg(
          delayed_flights=('FLIGHT_NUMBER', 'size'),
          avg_departure_delay=('DEPARTURE_DELAY', 'mean'),
          median_departure_delay=('DEPARTURE_DELAY', 'median'),
          avg_arrival_delay=('ARRIVAL_DELAY', 'mean')
      )
      .reset_index()
)

airline_stats = airline_stats[airline_stats['delayed_flights'] >= 30].sort_values('avg_departure_delay', ascending=False)

fig, ax = plt.subplots(figsize=(11, 6))
ax.bar(airline_stats['AIRLINE_CODE'], airline_stats['avg_departure_delay'])
ax.set_title('Средняя задержка вылета по авиакомпаниям')
ax.set_xlabel('Код авиакомпании')
ax.set_ylabel('Средняя задержка, минут')
plt.tight_layout()
plt.show()

for _, row in airline_stats[['AIRLINE_CODE', 'delayed_flights', 'avg_departure_delay']].head(10).iterrows():
    print(f"{row['AIRLINE_CODE']}: рейсов {int(row['delayed_flights'])}, средняя задержка {row['avg_departure_delay']:.1f} мин")
# Out:
# DL: рейсов 75, средняя задержка 77.6 мин
# AA: рейсов 237, средняя задержка 71.9 мин
# OO: рейсов 199, средняя задержка 57.4 мин
# UA: рейсов 231, средняя задержка 54.8 мин
# EV: рейсов 112, средняя задержка 53.4 мин
# MQ: рейсов 158, средняя задержка 47.6 мин
# B6: рейсов 96, средняя задержка 44.9 мин
# US: рейсов 104, средняя задержка 41.6 мин
# WN: рейсов 492, средняя задержка 40.0 мин
# F9: рейсов 57, средняя задержка 36.4 мин

# %% [markdown]
# Вывод.
#
# В этом срезе самые тяжёлые средние задержки у DL и AA. При этом WN даёт самый большой объём задержанных рейсов, но средняя тяжесть у неё заметно ниже. Это хороший пример того, что масштаб проблемы нужно смотреть сразу в двух измерениях: объём и сила задержки.

# %% [markdown]
# Результат 3. Есть ли концентрация проблемы в отдельных аэропортах?
#
# По аэропортам важно одновременно смотреть на два признака: сколько задержанных рейсов они дают и насколько сильны эти задержки. Тогда видно, где перегруженный узел, а где точечная, но тяжёлая проблема.

# %%
airport_stats = (
    fl.groupby(['ORIGIN_AIRPORT', 'ORIGIN_AIRPORT_NAME'])
      .agg(
          delayed_flights=('FLIGHT_NUMBER', 'size'),
          avg_departure_delay=('DEPARTURE_DELAY', 'mean')
      )
      .reset_index()
)

airport_plot = airport_stats[airport_stats['delayed_flights'] >= 10].copy()

fig, ax = plt.subplots(figsize=(10, 7))
ax.scatter(airport_plot['delayed_flights'], airport_plot['avg_departure_delay'])

for _, row in airport_plot.nlargest(10, 'delayed_flights').iterrows():
    ax.annotate(row['ORIGIN_AIRPORT'], (row['delayed_flights'], row['avg_departure_delay']),
                xytext=(4, 4), textcoords='offset points', fontsize=9)

ax.set_title('Аэропорты: объём задержек и их средняя тяжесть')
ax.set_xlabel('Число задержанных рейсов')
ax.set_ylabel('Средняя задержка вылета, минут')
plt.tight_layout()
plt.show()

top_volume = airport_plot.sort_values('delayed_flights', ascending=False).head(5)
top_severity = airport_plot.sort_values('avg_departure_delay', ascending=False).head(5)

print('Лидеры по числу задержанных рейсов:')
for _, row in top_volume.iterrows():
    print(f"{row['ORIGIN_AIRPORT']}: {int(row['delayed_flights'])} рейсов, средняя задержка {row['avg_departure_delay']:.1f} мин")

print('\nЛидеры по средней тяжести задержки:')
for _, row in top_severity.iterrows():
    print(f"{row['ORIGIN_AIRPORT']}: {int(row['delayed_flights'])} рейсов, средняя задержка {row['avg_departure_delay']:.1f} мин")
# Out:
# Лидеры по числу задержанных рейсов:
# DEN: 216 рейсов, средняя задержка 51.2 мин
# DFW: 192 рейсов, средняя задержка 63.1 мин
# ORD: 114 рейсов, средняя задержка 54.4 мин
# LAX: 89 рейсов, средняя задержка 40.5 мин
# PHX: 77 рейсов, средняя задержка 43.4 мин
#
# Лидеры по средней тяжести задержки:
# BOS: 23 рейсов, средняя задержка 98.3 мин
# IAD: 11 рейсов, средняя задержка 86.6 мин
# SJU: 12 рейсов, средняя задержка 79.2 мин
# DTW: 19 рейсов, средняя задержка 69.7 мин
# HNL: 10 рейсов, средняя задержка 65.3 мин

# %% [markdown]
# Вывод.
#
# По объёму особенно выделяются DEN и DFW. При этом есть аэропорты с меньшим числом задержанных рейсов, но с намного более тяжёлой средней задержкой, например BOS и IAD. Значит, часть аэропортов требует работы с пропускной способностью, а часть — более точечных операционных мер.

# %% [markdown]
# Результат 4. В какое время суток задержки становятся наиболее тяжёлыми?
#
# Картина по часам помогает увидеть накопление сбоев в течение дня. Чтобы не ошибиться с интерпретацией, полезно смотреть и на среднюю задержку, и на число рейсов.

# %%
hour_stats = (
    fl.groupby('SCHEDULED_HOUR')
      .agg(
          delayed_flights=('FLIGHT_NUMBER', 'size'),
          avg_departure_delay=('DEPARTURE_DELAY', 'mean')
      )
      .reset_index()
)

fig, ax1 = plt.subplots(figsize=(12, 5))
ax1.bar(hour_stats['SCHEDULED_HOUR'], hour_stats['delayed_flights'], alpha=0.7)
ax1.set_xlabel('Час запланированного вылета')
ax1.set_ylabel('Число задержанных рейсов')

ax2 = ax1.twinx()
ax2.plot(hour_stats['SCHEDULED_HOUR'], hour_stats['avg_departure_delay'], marker='o')
ax2.set_ylabel('Средняя задержка, минут')

ax1.set_title('Задержки по времени суток: объём и средняя тяжесть')
plt.tight_layout()
plt.show()

worst_hours = hour_stats.sort_values('avg_departure_delay', ascending=False).head(5)
for _, row in worst_hours.iterrows():
    print(f"Час {int(row['SCHEDULED_HOUR']):02d}:00 — средняя задержка {row['avg_departure_delay']:.1f} мин, рейсов {int(row['delayed_flights'])}")
# Out:
# Час 23:00 — средняя задержка 85.4 мин, рейсов 24
# Час 04:00 — средняя задержка 83.5 мин, рейсов 2
# Час 09:00 — средняя задержка 67.5 мин, рейсов 71
# Час 08:00 — средняя задержка 62.4 мин, рейсов 68
# Час 12:00 — средняя задержка 60.8 мин, рейсов 100

# %% [markdown]
# Вывод.
#
# Самые тяжёлые средние задержки наблюдаются поздно вечером, особенно около 23:00. Также заметен утренний всплеск примерно в 08:00–09:00. Это похоже на сочетание двух механизмов: сложный старт дневной волны и накопление сбоев к концу дня.

# %% [markdown]
# Результат 5. Есть ли маршруты, которые дают устойчивые очаги проблемы?
#
# Средние значения по аэропортам могут скрывать проблемы на конкретных направлениях. Поэтому отдельно посмотрим на повторяющиеся маршруты.

# %%
route_stats = (
    fl.groupby('ROUTE')
      .agg(
          delayed_flights=('FLIGHT_NUMBER', 'size'),
          avg_departure_delay=('DEPARTURE_DELAY', 'mean')
      )
      .reset_index()
)

route_plot = route_stats[route_stats['delayed_flights'] >= 5].sort_values('avg_departure_delay', ascending=False).head(12)

fig, ax = plt.subplots(figsize=(11, 6))
ax.barh(route_plot['ROUTE'], route_plot['avg_departure_delay'])
ax.set_title('Маршруты с самой тяжёлой повторяющейся задержкой')
ax.set_xlabel('Средняя задержка, минут')
ax.set_ylabel('Маршрут')
ax.invert_yaxis()
plt.tight_layout()
plt.show()

for _, row in route_plot.iterrows():
    print(f"{row['ROUTE']}: рейсов {int(row['delayed_flights'])}, средняя задержка {row['avg_departure_delay']:.1f} мин")
# Out:
# ORD → DFW: рейсов 11, средняя задержка 103.6 мин
# LAX → PHX: рейсов 6, средняя задержка 82.0 мин
# DEN → LAX: рейсов 7, средняя задержка 79.9 мин
# DFW → DEN: рейсов 6, средняя задержка 78.7 мин
# DFW → SAT: рейсов 6, средняя задержка 78.0 мин
# DFW → LAS: рейсов 7, средняя задержка 70.4 мин
# DFW → MIA: рейсов 5, средняя задержка 68.2 мин
# DEN → SAN: рейсов 5, средняя задержка 66.6 мин
# LAX → HNL: рейсов 6, средняя задержка 59.5 мин
# DEN → PHX: рейсов 8, средняя задержка 51.6 мин
# DEN → IAD: рейсов 5, средняя задержка 46.2 мин
# LIH → HNL: рейсов 5, средняя задержка 43.8 мин

# %% [markdown]
# Вывод.
#
# Некоторые пары аэропортов выглядят как устойчивые точки риска, а не как случайные единичные сбои. Самый заметный пример — ORD → DFW. Это полезно для практики, потому что маршрутный уровень лучше связывает проблему с расписанием, оборотом самолёта и координацией слотов.

# %% [markdown]
# Результат 6. Почему одной средней недостаточно: сравнение всех рейсов AS и DL за день
#
# Даже если доля задержек близка, профиль риска может различаться. Чтобы это показать, сравним две авиакомпании по полным дневным данным, а не только по задержанным рейсам.

# %%
benchmark = pd.concat([
    as_flights.assign(AIRLINE_GROUP='AS'),
    dl_flights.assign(AIRLINE_GROUP='DL')
], ignore_index=True)

benchmark_stats = (
    benchmark.groupby('AIRLINE_GROUP')
             .agg(
                 flights=('FLIGHT_NUMBER', 'size'),
                 share_delayed=('DEPARTURE_DELAY', lambda s: (s > 0).mean() * 100),
                 avg_departure_delay=('DEPARTURE_DELAY', 'mean'),
                 median_departure_delay=('DEPARTURE_DELAY', 'median'),
                 p90_departure_delay=('DEPARTURE_DELAY', lambda s: s.quantile(0.90)),
                 max_departure_delay=('DEPARTURE_DELAY', 'max')
             )
             .reset_index()
)

plot_df = benchmark_stats.set_index('AIRLINE_GROUP')[['share_delayed', 'avg_departure_delay', 'p90_departure_delay', 'max_departure_delay']]

fig, ax = plt.subplots(figsize=(10, 5))
x = np.arange(len(plot_df.columns))
width = 0.35

ax.bar(x - width/2, plot_df.loc['AS'], width, label='AS')
ax.bar(x + width/2, plot_df.loc['DL'], width, label='DL')

ax.set_xticks(x)
ax.set_xticklabels(['Доля задержанных, %', 'Средняя задержка', '90-й перцентиль', 'Максимум'], rotation=15)
ax.set_title('Сравнение AS и DL по полным дневным данным')
ax.set_ylabel('Минуты или проценты')
ax.legend()
plt.tight_layout()
plt.show()

for _, row in benchmark_stats.iterrows():
    print(
        f"{row['AIRLINE_GROUP']}: рейсов {int(row['flights'])}, "
        f"доля задержанных {row['share_delayed']:.1f}%, "
        f"средняя {row['avg_departure_delay']:.1f} мин, "
        f"90-й перцентиль {row['p90_departure_delay']:.1f} мин, "
        f"максимум {row['max_departure_delay']:.0f} мин"
    )
# Out:
# AS: рейсов 440, доля задержанных 24.5%, средняя 1.2 мин, 90-й перцентиль 14.0 мин, максимум 160 мин
# DL: рейсов 1559, доля задержанных 25.2%, средняя 3.4 мин, 90-й перцентиль 12.0 мин, максимум 860 мин

# %% [markdown]
# Вывод.
#
# У AS и DL доля задержанных вылетов близка, но профиль риска различается. У DL заметно выше средняя задержка и особенно сильно выделяется максимум. Значит, одной средней или одной доли задержек мало: хвост распределения тоже важен, потому что именно он даёт самые дорогие операционные сбои.

# %% [markdown]
# Итоговые выводы.
#
# 1. В этом срезе система задержек формируется в первую очередь внутренними операционными причинами, а не погодой.
# 2. Для авиакомпаний важно смотреть одновременно на объём задержанных рейсов и на среднюю тяжесть задержки.
# 3. Основные точки концентрации по объёму — DEN и DFW, но есть аэропорты с меньшим объёмом и очень тяжёлой средней задержкой.
# 4. К концу дня задержки в среднем становятся тяжелее, что похоже на накопление сбоев.
# 5. Некоторые маршруты ведут себя как устойчивые очаги риска и требуют отдельного анализа.
# 6. При сравнении авиакомпаний одной средней недостаточно: редкие, но очень тяжёлые случаи могут сильно менять реальную картину.
