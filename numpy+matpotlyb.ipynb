# %% [markdown]
# <a href="https://colab.research.google.com/github/Timur228228228/-/blob/main/numpy%2Bmatpotlyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

years = np.array([1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920])
hares = np.array([30, 47.2, 70.2, 77.4, 36.3, 20.6, 18.1, 21.4, 22, 25.4, 27.1, 40.3, 57, 76.6, 52.3, 19.5, 11.2, 7.6, 14.6, 16.2, 24.7]) * 1000
lynxes = np.array([4, 6.1, 9.8, 35.2, 59.4, 41.7, 19, 13, 8.3, 9.1, 7.4, 8, 12.3, 19.5, 45.7, 51.1, 29.7, 15.8, 9.7, 10.1, 8.6]) * 1000
carrots = np.array([48300, 48200, 41500, 38200, 40600, 39800, 38600, 42300, 44500, 42100, 46000, 46800, 43800, 40900, 39400, 39000, 36700, 41800, 43300, 41300, 47300])

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Let $f(x) = 2\sin x - \cos{2x}$. Write a function `beauty_derivative_plot` that takes a point $x$ and plots the function $f(x)$ and its derivative $f'(x)$ in the range $x \in [-2\pi, 2\pi]$. The function should also plot the tangent line to the function at the point $x$.
#
# Example of output for $x = -3, -2, 1.7$:
#
# ```python
# beauty_derivative_plot(-3)
# ```
# <img src="https://i.ibb.co/zTdYLC0J/tangent-line-3-0.png" width="600"/>
#
# ```python
# beauty_derivative_plot(-2)
# ```
# <img src="https://i.ibb.co/hFXNZ7wS/tangent-line-2-0.png" width="600"/>
#
# ```python
# beauty_derivative_plot(1.7)
# ```
# <img src="https://i.ibb.co/217yHstn/tangent-line-1-7.png" width="600"/>

# %%
def beauty_derivative_plot(x):

    import numpy as np
    import matplotlib.pyplot as plt

    f = lambda x: 2 * np.sin(x) - np.cos(2*x)
    df = lambda x: 2 * np.cos(x) + 2 * np.sin(2*x)

    x_vals = np.linspace(-2*np.pi, 2*np.pi, 400)
    y_vals = f(x_vals)
    dy_vals = df(x_vals)

    y0 = f(x)
    dy0 = df(x)

    tangent = y0 + dy0 * (x_vals - x)

    plt.figure(figsize=(8, 5))

    plt.plot(x_vals, y_vals, 'b-', label=r'$f(x) = 2\sin x - \cos 2x$')
    plt.plot(x_vals, dy_vals, 'g-', label=r"$f'(x)$")
    plt.plot(x_vals, tangent, 'r--', label='tangent line')
    plt.plot(x, y0, 'ro', markersize=8, label='point')
    plt.grid(True)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend(loc='upper right')
    plt.xlim(-2*np.pi, 2*np.pi)
    plt.ylim(-5, 5)
    plt.title(f'Tangent line at x = {x:.2f}')
    plt.show()

# %% [markdown]
# ## Problem 2

# %% [markdown]
# The data in [populations.txt](http://www.scipy-lectures.org/_downloads/populations.txt) describes the populations of hares, lynxes and carrots in northern Canada during 20 years. Get the data with
# ```python
# np.loadtxt('http://www.scipy-lectures.org/_downloads/populations.txt')
# ```
# and do the following exercises **without for-loops (!!!)**.

# %% [markdown]
# - Plot the population size of each species for each year on a single graph. Add legend and axis labels to the plot.

# %%
plt.figure(figsize=(10, 5))
plt.plot(years, hares, 'o-', label='Hares')
plt.plot(years, lynxes, 's-', label='Lynxes')
plt.plot(years, carrots, '^-', label='Carrots')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.title('Population sizes over years')
plt.show()

# %% [markdown]
# - Find which year each species had the largest population. Mark these years in the plot of populations.

# %%
max_hares_year = years[np.argmax(hares)]
max_lynxes_year = years[np.argmax(lynxes)]
max_carrots_year = years[np.argmax(carrots)]

print(f"Max hares: {max_hares_year}, max lynxes: {max_lynxes_year}, max carrots: {max_carrots_year}")


plt.figure(figsize=(10, 5))
plt.plot(years, hares, 'o-', label='Hares')
plt.plot(years, lynxes, 's-', label='Lynxes')
plt.plot(years, carrots, '^-', label='Carrots')
plt.plot(max_hares_year, np.max(hares), 'ro', markersize=12)
plt.plot(max_lynxes_year, np.max(lynxes), 'gs', markersize=12)
plt.plot(max_carrots_year, np.max(carrots), 'b^', markersize=12)
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.title('Population sizes with maxima marked')
plt.show()
# Out:
# Max hares: 1903, max lynxes: 1904, max carrots: 1900

# %% [markdown]
# - Assuming total population of hares and lynxes is 100%, plot stacked bar graph showing ratio of each specis for each year in the period.

# %%
total_hl = hares + lynxes
hare_frac = hares / total_hl
lynx_frac = lynxes / total_hl

plt.figure(figsize=(10, 5))
plt.bar(years, hare_frac, label='Hares', width=0.8)
plt.bar(years, lynx_frac, bottom=hare_frac, label='Lynxes', width=0.8)
plt.xlabel('Year')
plt.ylabel('Fraction')
plt.title('Relative populations of hares and lynxes')
plt.legend()
plt.grid(True, axis='y')
plt.show()

# %% [markdown]
# - Find the mean and std of the populations of each species. Plot the historgam of population for each species and show mean values with vertical line. Show each histogram in a separate plot. Arrange 3 plots in a row.

# %%
mean_hares, std_hares = np.mean(hares), np.std(hares)
mean_lynxes, std_lynxes = np.mean(lynxes), np.std(lynxes)
mean_carrots, std_carrots = np.mean(carrots), np.std(carrots)

print(f"Hares: mean = {mean_hares:.1f}, std = {std_hares:.1f}")
print(f"Lynxes: mean = {mean_lynxes:.1f}, std = {std_lynxes:.1f}")
print(f"Carrots: mean = {mean_carrots:.1f}, std = {std_carrots:.1f}")

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
axes[0].hist(hares, bins=8, color='lightblue', edgecolor='black')
axes[0].axvline(mean_hares, color='red', linestyle='--', label='mean')
axes[0].set_title('Hares')
axes[0].set_xlabel('Population')
axes[0].set_ylabel('Frequency')
axes[0].legend()

axes[1].hist(lynxes, bins=8, color='lightgreen', edgecolor='black')
axes[1].axvline(mean_lynxes, color='red', linestyle='--', label='mean')
axes[1].set_title('Lynxes')
axes[1].set_xlabel('Population')
axes[1].set_ylabel('Frequency')
axes[1].legend()

axes[2].hist(carrots, bins=8, color='lightcoral', edgecolor='black')
axes[2].axvline(mean_carrots, color='red', linestyle='--', label='mean')
axes[2].set_title('Carrots')
axes[2].set_xlabel('Population')
axes[2].set_ylabel('Frequency')
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# Hares: mean = 34081.0, std = 20897.9
# Lynxes: mean = 20166.7, std = 16254.6
# Carrots: mean = 42400.0, std = 3322.5

# %% [markdown]
# - Find which species (hares or lynxes) has the largest population for each year. Print the result as [H, H, L, H, ...]. Plot a pie chart showing the ratio of "H" and "L" values.

# %%
dominant = np.where(hares > lynxes, 'H', 'L')
print("Dominant species each year:", dominant)

unique, counts = np.unique(dominant, return_counts=True)
plt.figure(figsize=(5,5))
plt.pie(counts, labels=unique, autopct='%1.1f%%', startangle=90)
plt.title('Dominant species (hares vs lynxes)')
plt.show()
# Out:
# Dominant species each year: ['H' 'H' 'H' 'H' 'L' 'L' 'L' 'H' 'H' 'H' 'H' 'H' 'H' 'H' 'H' 'L' 'L' 'L'
#  'H' 'H' 'H']

# %% [markdown]
# - Plot the change in the hare population and in the lynx population for each year. Find the correlation coefficient between the both time series.

# %%
diff_hares = np.diff(hares)
diff_lynxes = np.diff(lynxes)
years_diff = years[1:]

plt.figure(figsize=(10,5))
plt.plot(years_diff, diff_hares, 'o-', label='Hares change')
plt.plot(years_diff, diff_lynxes, 's-', label='Lynxes change')
plt.xlabel('Year')
plt.ylabel('Population change')
plt.legend()
plt.grid(True)
plt.title('Yearly population changes')
plt.show()

corr = np.corrcoef(diff_hares, diff_lynxes)[0,1]
print(f"Correlation between changes: {corr:.3f}")
# Out:
# Correlation between changes: -0.178

# %% [markdown]
# - Using a scatter plot, show the population of hares vs lynxes by year (each point corresponds to a particular year, and the point coordinates correspond to the population of the two species in that year).

# %%
plt.figure(figsize=(6,6))
plt.scatter(hares, lynxes, c=years, cmap='viridis', s=50)
plt.xlabel('Hares')
plt.ylabel('Lynxes')
plt.title('Hares vs Lynxes by year')
plt.colorbar(label='Year')
plt.grid(True)
plt.show()

# %% [markdown]
# - Assume the population of hares in 1920 is unknown. Suggest a way to estimate this value. Compare an estimated value
# with the true value and print a ratio of the error to the true value.

# %%
coeffs = np.polyfit(years, hares, 1)
linear_fit = np.poly1d(coeffs)
estimated_1920 = linear_fit(1920)
true_1920 = hares[-1]
error_ratio = abs(estimated_1920 - true_1920) / true_1920

print(f"Estimated hare population in 1920: {estimated_1920:.1f}")
print(f"True value: {true_1920}")
print(f"Relative error: {error_ratio:.3f}")
# Out:
# Estimated hare population in 1920: 20649.8
# True value: 24700.0
# Relative error: 0.164
